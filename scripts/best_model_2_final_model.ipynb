# %%
import torch

# %%
model = torch.load("/home/chen/workshop/thesis/human-pose-estimation.pytorch/output/crowdpose/pose_resnet_50/branch_256x192_d256x3_adam_lr1e-3/model_best_final.pth.tar")

# %%
checkpoint = torch.load("/home/chen/workshop/thesis/human-pose-estimation.pytorch/output/crowdpose/pose_resnet_50/branch_256x192_d256x3_adam_lr1e-3/checkpoint.pth.tar")

# %%
checkpoint.keys()
# Out:
# dict_keys(['epoch', 'model', 'state_dict', 'module.state_dict', 'perf', 'optimizer'])

# %%
checkpoint['optimizer']
# Out:
# 2.7212e-08,  5.7056e-08, -1.9442e-08,
#            -4.5461e-09, -4.0908e-08, -4.0550e-08,  7.9713e-08,  4.5580e-08,
#             9.4213e-08, -8.3445e-08,  2.9465e-08, -1.7574e-08,  4.4769e-08,
#            -2.3240e-07, -8.3280e-09, -6.7251e-08, -8.0534e-08,  3.5008e-07,
#            -9.4694e-09,  2.2967e-07,  8.6694e-08, -3.3484e-08, -5.2477e-08,
#            -3.0554e-08, -1.0610e-07, -2.0700e-08, -2.5223e-07, -1.2035e-07,
#             2.9351e-08,  8.3390e-08, -1.5113e-07, -1.2268e-07, -1.2765e-08,
#            -2.1812e-08, -5.5032e-08, -3.8050e-09, -5.2503e-08, -7.6647e-08,
#            -1.6677e-09, -3.9057e-08, -1.8396e-08,  4.3109e-08, -7.6287e-08,
#            -1.0585e-07,  8.0163e-08,  4.7397e-08, -2.9762e-08,  4.7972e-08,
#            -1.0846e-08, -3.7666e-08, -5.3967e-08, -9.2153e-08,  8.5094e-08,
#             7.5195e-09, -2.5419e-07,  2.7896e-09, -2.0759e-08,  4.5710e-08,
#            -7.4579e-09, -1.4817e-08,  4.1601e-08,  1.6518e-08,  5.0872e-08,
# ...
